# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 435.7 kB/s eta 0:01:29
#    ---------------------------------------- 0.0/38.6 MB 279.3 kB/s eta 0:02:19
#    ---------------------------------------- 0.1/38.6 MB 326.1 kB/s eta 0:01:59
#    ---------------------------------------- 0.1/38.6 MB 327.3 kB/s eta 0:01:58
#    ---------------------------------------- 0.1/38.6 MB 327.3 kB/s eta 0:01:58
#    ---------------------------------------- 0.1/38.6 MB 290.5 kB/s eta 0:02:13
#    ---------------------------------------- 0.1/38.6 MB 297.7 kB/s eta 0:02:10
#    ---------------------------------------- 0.1/38.6 MB 276.8 kB/s eta 0:02:20
#    ---------------------------------------- 0.1/38.6 MB 293.2 kB/s eta 0:02:12
# ...

# %%
import cv2
import numpy as np

# Load input video
input_video = cv2.VideoCapture(r"D:/project/latest.mp4")

# Load advertisement image
advertisement_image = cv2.imread(r"D:/project/advertisement_image.jpg")

if advertisement_image is None:
    print("Error: Could not load advertisement image.")
    exit()
    
# Initialize ORB feature detector
orb = cv2.ORB_create()

# Initialize Brute-Force Matcher
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# Read the first frame
ret, prev_frame = input_video.read()
if ret:
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    prev_keypoints, prev_descriptors = orb.detectAndCompute(prev_gray, None)
else:
    print("Error reading the first frame from the input video")
    exit()  # Exit the script if the first frame cannot be read

# %%
import os

file_path = "D:\project\INP.mp4"
if os.access(file_path, os.R_OK):
    print("Read permission is granted for the file.")
else:
    print("Read permission is not granted for the file.")
# Out:
# Read permission is granted for the file.

# %%
end_of_video = False

while True:
    # Read the next frame
    ret, frame = input_video.read()
    if not ret:
        end_of_video = True
        print("End of video reached.")
        break
# Check if the loop terminated due to reaching the end of the video file
if end_of_video:
    print("End of video reached.")
else:
    print("Error occurred during reading.")
# Out:
# End of video reached.
# End of video reached.

# %%
if frame is not None and not frame.empty():
    # Process the frame
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
else:
    print("Error: Empty frame or frame could not be read")
# Out:
# Error: Empty frame or frame could not be read

# %%
orb = cv2.ORB_create()
# Detect keypoints and descriptors in the current frame
keypoints, descriptors = orb.detectAndCompute(gray, None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 orb = cv2.ORB_create()
#       2 # Detect keypoints and descriptors in the current frame
# ----> 3 keypoints, descriptors = orb.detectAndCompute(gray, None)
#
# NameError: name 'gray' is not defined

# %%
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
# Match descriptors between consecutive frames
matches = bf.match(prev_descriptors, descriptors)
        
# Sort matches by distance
matches = sorted(matches, key=lambda x: x.distance)

# %%
*******************
# Out:
#   Cell In[1], line 1
#     *******************
#     ^
# SyntaxError: invalid syntax

# %%
src_pts = np.float32([prev_keypoints[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
dst_pts = np.float32([keypoints[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)
    
    # Calculate homography matrix
H, _ = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)

print("Frame:", frame)
if frame is not None:
    print("Frame Shape:", frame.shape)
    
print("Homography Matrix (H):", H)
print("Frame Shape:", frame.shape)



# Warp advertisement image to fit the current frame
warped_advertisement = cv2.warpPerspective(advertisement_image, H, (frame.shape[1], frame.shape[0]))

    # Warp advertisement image to fit the current frame
warped_advertisement = cv2.warpPerspective(advertisement_image, H, (frame.shape[1], frame.shape[0]))
    
    # Insert the advertisement image into the frame
output = cv2.addWeighted(frame, 1, warped_advertisement, 0.5, 0)
    
    # Display the result
cv2.imshow("Output", output)
    
    # Break the loop if 'q' is pressed
if cv2.waitKey(25) & 0xFF == ord('q'):
    break
    
    # Update previous frame
prev_gray = gray.copy()
prev_keypoints = keypoints
prev_descriptors = descriptors

# Release video capture
input_video.release()
cv2.destroyAllWindows()
# Out:
# Frame: None
# Homography Matrix (H): [[ 1.33303399e+00  1.02642393e-02 -3.37452096e+02]
#  [ 2.89059355e-01  1.30875069e+00 -5.65453381e+02]
#  [ 1.11657329e-04  3.12366742e-05  1.00000000e+00]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 12
#       9     print("Frame Shape:", frame.shape)
#      11 print("Homography Matrix (H):", H)
# ---> 12 print("Frame Shape:", frame.shape)
#      16 # Warp advertisement image to fit the current frame
#      17 warped_advertisement = cv2.warpPerspective(advertisement_image, H, (frame.shape[1], frame.shape[0]))
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
while True:
    # Read the next frame
    ret, frame = input_video.read()
    
    # Check if frame was read successfully
    if not ret:
        print("End of video reached.")
        break
# Out:
# End of video reached.

# %%
ret, frame = input_video.read()

if ret:
    print("Frame read successfully")
else:
    print("Failed to read frame")
# Out:
# Failed to read frame

# %%
import cv2

# Open the video file
input_video = cv2.VideoCapture("video_file_path.mp4")  # Update with your video file path

# Check if the video file was opened successfully
if not input_video.isOpened():
    print("Error: Could not open video file")
else:
    # Get codec information
    codec_info = input_video.get(cv2.CAP_PROP_FOURCC)
    
    # Convert codec information to a readable format
    codec_str = "".join([chr((int(codec_info) >> 8 * i) & 0xFF) for i in range(4)])
    
    print("Video codec: ", codec_str)
    
    # Release video capture
    input_video.release()
# Out:
# Error: Could not open video file

# %%
import cv2
import numpy as np
from skimage import feature
from scipy.ndimage import distance_transform_edt

# Load advertisement image and video
advertisement_image = cv2.imread("advertisement_image.png", cv2.IMREAD_UNCHANGED)
input_video = cv2.VideoCapture("Input_Video_2.mp4")

# Feature detection and matching
# Implement feature detection and matching techniques (e.g., SIFT, ORB, AKAZE)

# Occlusion detection
# Analyze matched keypoints to identify occluded regions
# Implement motion detection or optical flow to detect moving objects

# Occlusion handling
# Implement strategies to handle occlusions gracefully

# Insert advertisement
while True:
    ret, frame = input_video.read()
    if not ret:
        break
    
    # Resize advertisement image to match insertion scale
    resized_advertisement = cv2.resize(advertisement_image, (frame.shape[1], frame.shape[0]))
    
    # Overlay advertisement onto video frame
    # Apply any necessary transformations (e.g., scaling, rotation) to match perspective
    
    # Display result
    cv2.imshow("Advertisement Insertion", frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# Release video capture
input_video.release()
cv2.destroyAllWindows()

# %%
# upper and lower range of HSV
lower = np.array([6,10,68])
upper = np.array([30,36,122])

# create kernel for image dilation
kernel = np.ones((3,3),np.uint8)

# execute the couple of lines below everytime you run the following while loop
cap = cv2.VideoCapture("D:/project+latest.mp4")
cnt = 0

# loop to load, pre-process and display the frames
while(True):
    ret, f = cap.read()
    
    # extract the area where we will place the logo
    # the dimensions of this area should match with those of the logo
    mini_frame = f[500:740,875:1070,:]
    
    # create HSV image
    hsv = cv2.cvtColor(f, cv2.COLOR_BGR2HSV)
    
    # create binary mask 
    mask = cv2.inRange(hsv, lower, upper)
    
    # perform dilation on the mask to reduce noise
    dil = cv2.dilate(mask,kernel,iterations = 5)
    
    # extract the area where we will place the logo
    # create 3 channels 
    mini_dil = np.zeros_like(mini_frame)
    mini_dil[:,:,0] = dil[500:740,875:1070]
    mini_dil[:,:,1] = dil[500:740,875:1070]
    mini_dil[:,:,2] = dil[500:740,875:1070]
    
    # copy image of logo
    logo_copy = logo.copy()
    
    # set pixel values to 1 where the pixel values of the mask is 0
    logo_copy[mini_dil == 0] = 1
    
    # set pixel values to 1 where the pixel values of the logo is 0
    logo_copy[logo == 0] = 1    
    
    # set pixel values to 1 where the pixel values of the logo is not 1
    mini_frame[logo_copy != 1] = 1
    
    # merge images (array multiplication)
    mini_frame = mini_frame*logo_copy
    
    # insert logo in the frame
    f[500:740,875:1070,:] = mini_frame
    
    # resize the frame (optional)
    f = cv2.resize(f, (480, 270), interpolation = cv2.INTER_AREA)

    # display frame
    cv2.imshow('frame', f)
    
    # save frame
    # cv2.imwrite(path+'frames/'+str(cnt)+'.png',f)
    cnt+= 1
    
    if cv2.waitKey(20) & 0xFF == ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 18
#      14 ret, f = cap.read()
#      16 # extract the area where we will place the logo
#      17 # the dimensions of this area should match with those of the logo
# ---> 18 mini_frame = f[500:740,875:1070,:]
#      20 # create HSV image
#      21 hsv = cv2.cvtColor(f, cv2.COLOR_BGR2HSV)
#
# TypeError: 'NoneType' object is not subscriptable
